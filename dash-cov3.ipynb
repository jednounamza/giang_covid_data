# %% [markdown]
# # Cleaning the data frame
# ## We download the latest corona data from:
# ## https://data.europa.eu/euodp/en/data/dataset/covid-19-coronavirus-data
# COVID-19 cases worldwide CSV file \
# We load the data directly into a Pandas DataFrame. Pandas provides a function, read_csv(), which can take a data and return a DataFrame object as we obtain below:
#
# I selected an appropriate dataset from the datasets that are freely downloadable from the net:
#
# https://data.europa.eu/euodp/en/data/dataset/covid-19-coronavirus-data \
# I downloaded the CSV file the latest corona data using the link:
#
# COVID-19 cases worldwide CSV.
#
# This file is data1.csv (about 600 kB).
#
# I have loaded this file directly into a Pandas DataFrame. And I used a function, read\_csv(), which can take a CSV file and return a DataFrame object.
#
# I obtained 9791 rows x 10 columns.

# %%
import pycountry
import plotly.express as px
import pandas as pd
DATASET = r'/home/h31bnj24/3/97/data1.csv'
df1 = pd.read_csv(DATASET)
print(df1.head(4))  # I get first 4 entries in the dataframe
print(df1.tail(4))  # I get last 4 entries in the dataframe
# Out:
#       dateRep year_week  cases_weekly  deaths_weekly countriesAndTerritories  \
# 0  11/01/2021   2021-01           675             71             Afghanistan
# 1  04/01/2021   2020-53           902             60             Afghanistan
# 2  28/12/2020   2020-52          1994             88             Afghanistan
# 3  21/12/2020   2020-51           740            111             Afghanistan
#
#   geoId countryterritoryCode  popData2019 continentExp  \
# 0    AF                  AFG   38041757.0         Asia
# 1    AF                  AFG   38041757.0         Asia
# 2    AF                  AFG   38041757.0         Asia
# 3    AF                  AFG   38041757.0         Asia
#
#    notification_rate_per_100000_population_14-days
# 0                                             4.15
# 1                                             7.61
# 2                                             7.19
# 3                                             6.56
# ...

# %% [markdown]
# # From output, you can see that the DataFrame (df1) has the following columns:
#
# dateRep \
# year_week \
# cases_weekly \
# deaths_weekly \
# countriesAndTerritories \
# geoId \
# countryterritoryCode \
# popData2019 \
# continentExp \
# notification_rate_per_100000_population_14-days \
#
# We can see that the dateRep column has entries starting from 06/01/2020 to 11/01/2021
#
# I used the following methon in order to replace NaN values with zeros in Pandas DataFrame:
#
# df1=df1.fillna(0)

# %%
dl=len(df1)
print(dl)
df1=df1.fillna(0)
print(df1.tail(60))
# Out:
# 9791
#          dateRep year_week  cases_weekly  deaths_weekly  \
# 9731  13/07/2020   2020-28           263             12
# 9732  06/07/2020   2020-27            75              8
# 9733  29/06/2020   2020-26           127             11
# 9734  22/06/2020   2020-25            72              0
# 9735  15/06/2020   2020-24           204              4
# 9736  08/06/2020   2020-23            97              0
# 9737  01/06/2020   2020-22           137              0
# 9738  25/05/2020   2020-21           167              0
# 9739  18/05/2020   2020-20           486              0
# 9740  11/05/2020   2020-19           143              4
# 9741  04/05/2020   2020-18            36              0
# 9742  27/04/2020   2020-17            27              0
# 9743  20/04/2020   2020-16            18              1
# 9744  13/04/2020   2020-15             4              1
# 9745  06/04/2020   2020-14            10              1
# 9746  30/03/2020   2020-13            26              0
# ...

# %% [markdown]
# I need to create a list of all countries in the database. This was required because in the df1, in the column countriesAndTerritories, each country was figuring for each date. So in effect, the countriesAndTerritories column had multiple entries for each country. Therefore we use the unique().tolist() functions:
#
# list_countries = df1['countriesAndTerritories'].unique().tolist()

# %%
list_countries = df1['countriesAndTerritories'].unique().tolist()
print(list_countries)
# Out:
# ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla', 'Antigua_and_Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire, Saint Eustatius and Saba', 'Bosnia_and_Herzegovina', 'Botswana', 'Brazil', 'British_Virgin_Islands', 'Brunei_Darussalam', 'Bulgaria', 'Burkina_Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape_Verde', 'Cases_on_an_international_conveyance_Japan', 'Cayman_Islands', 'Central_African_Republic', 'Chad', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Costa_Rica', 'Cote_dIvoire', 'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czechia', 'Democratic_Republic_of_the_Congo', 'Denmark', 'Djibouti', 'Dominica', 'Dominican_Republic', 'Ecuador', 'Egypt', 'El_Salvador', 'Equatorial_Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia', 'Falkland_Islands_(Malvinas)', 'Faroe_Islands', 'Fiji', 'Finland', 
# ...
